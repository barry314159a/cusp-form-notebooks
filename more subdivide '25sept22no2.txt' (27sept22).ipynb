# %%
def stripQuotationMarks(string):
    var('x')
    return sage_eval(string,locals={'x':x})

# %%
# from 'superlong H4 24sept22'
# print output snipped.
data=[]
import time
start=time.time()/60
for m in [1204..2403]:
    poly=H4(200,m)
    data=data+[[m,poly]]
    finish=time.time()/60
    print([m,poly.degree(),finish-start])
import pickle
wfile = open('/Users/barrybrent/25sept22no2.txt','wb') # H4 series 
s = pickle.dumps(str(data))
wfile.write(s)
wfile.close()

# %%
import pickle
rfile = open('/Users/barrybrent/25sept22no2.txt','rb') # H4 series
rs=pickle.load(rfile)
rfile.close()
s=stripQuotationMarks(rs)
print(len(s))
# Out:
# 1200

# %%
import pickle
rfile = open('/Users/barrybrent/25sept22no2.txt','rb') # H4 series
rs=pickle.load(rfile)
rfile.close()
s=stripQuotationMarks(rs)

data=[]
for k in [601..625]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/26sept22no26a.txt','wb') # H4 series 
t= pickle.dumps(str(data))
w.write(t)
w.close()

data=[]
for k in [626..650]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/26sept22no26b.txt','wb') # H4 series 
t= pickle.dumps(str(data))
w.write(t)
w.close()
# Out:
# 1805
# 1806
# 1807
# 1808
# 1809
# 1810
# 1811
# 1812
# 1813
# 1814
# 1815
# 1816
# 1817
# 1818
# 1819
# 1820
# 1821
# 1822
# 1823
# 1824
# 1825
# 1826
# 1827
# 1828
# 1829
# 1830
# 1831
# 1832
# 1833
# 1834
# 1835
# 1836
# 1837
# 1838
# 1839
# 1840
# 1841
# 1842
# 1843
# 1844
# 1845
# 1846
# 1847
# 1848
# 1849
# 1850
# 1851
# 1852
# 1853
# 1854

# %%
import pickle
rfile = open('/Users/barrybrent/25sept22no2.txt','rb') # H4 series
rs=pickle.load(rfile)
rfile.close()
s=stripQuotationMarks(rs)

data=[]
for k in [651..675]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/26sept22no27a.txt','wb') # H4 series 
t= pickle.dumps(str(data))
w.write(t)
w.close()

data=[]
for k in [676..700]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/26sept22no27b.txt','wb') # H4 series 
t= pickle.dumps(str(data))
w.write(t)
w.close()
# Out:
# 1855
# 1856
# 1857
# 1858
# 1859
# 1860
# 1861
# 1862
# 1863
# 1864
# 1865
# 1866
# 1867
# 1868
# 1869
# 1870
# 1871
# 1872
# 1873
# 1874
# 1875
# 1876
# 1877
# 1878
# 1879
# 1880
# 1881
# 1882
# 1883
# 1884
# 1885
# 1886
# 1887
# 1888
# 1889
# 1890
# 1891
# 1892
# 1893
# 1894
# 1895
# 1896
# 1897
# 1898
# 1899
# 1900
# 1901
# 1902
# 1903
# 1904

# %%
 import pickle
rfile = open('/Users/barrybrent/25sept22no2.txt','rb') # H4 series
rs=pickle.load(rfile)
rfile.close()
s=stripQuotationMarks(rs)

data=[]
for k in [701..725]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/26sept22no28a.txt','wb') # H4 series 
t= pickle.dumps(str(data))
w.write(t)
w.close()

data=[]
for k in [726..750]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/26sept22no28b.txt','wb') # H4 series 
t= pickle.dumps(str(data))
w.write(t)
w.close()

data=[]
for k in [751..775]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/26sept22no29a.txt','wb') # H4 series 
t= pickle.dumps(str(data))
w.write(t)
w.close()

data=[]
for k in [776..800]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/26sept22no29b.txt','wb') # H4 series 
t= pickle.dumps(str(data))
w.write(t)
w.close()

data=[]
for k in [801..825]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/26sept22no30a.txt','wb') # H4 series 
t= pickle.dumps(str(data))
w.write(t)
w.close()

data=[]
for k in [826..850]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/26sept22no30b.txt','wb') # H4 series 
t= pickle.dumps(str(data))
w.write(t)
w.close()

data=[]
for k in [851..875]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/26sept22no31a.txt','wb') # H4 series 
t= pickle.dumps(str(data))
w.write(t)
w.close()

data=[]
for k in [876..900]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/26sept22no31b.txt','wb') # H4 series 
t= pickle.dumps(str(data))
w.write(t)
w.close()

data=[]
for k in [901..925]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/26sept22no32a.txt','wb') # H4 series 
t= pickle.dumps(str(data))
w.write(t)
w.close()

data=[]
for k in [926..950]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/26sept22no32b.txt','wb') # H4 series 
t= pickle.dumps(str(data))
w.write(t)
w.close()

data=[]
for k in [951..975]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/26sept22no33a.txt','wb') # H4 series 
t= pickle.dumps(str(data))
w.write(t)
w.close()

data=[]
for k in [976..1000]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/26sept22no33b.txt','wb') # H4 series 
t= pickle.dumps(str(data))
w.write(t)
w.close()

data=[]
for k in [1001..1025]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/26sept22no34a.txt','wb') # H4 series 
t= pickle.dumps(str(data))
w.write(t)
w.close()

data=[]
for k in [1026..1050]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/26sept22no34b.txt','wb') # H4 series 
t= pickle.dumps(str(data))
w.write(t)
w.close()

data=[]
for k in [1051..1075]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/26sept22no35a.txt','wb') # H4 series 
t= pickle.dumps(str(data))
w.write(t)
w.close()

data=[]
for k in [1076..1100]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/26sept22no35b.txt','wb') # H4 series 
t= pickle.dumps(str(data))
w.write(t)
w.close()

data=[]
for k in [1101..1125]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/26sept22no36a.txt','wb') # H4 series 
t= pickle.dumps(str(data))
w.write(t)
w.close()

data=[]
for k in [1126..1150]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/26sept22no36b.txt','wb') # H4 series 
t= pickle.dumps(str(data))
w.write(t)
w.close()

data=[]
for k in [1151..1175]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/26sept22no37a.txt','wb') # H4 series 
t= pickle.dumps(str(data))
w.write(t)
w.close()

data=[]
for k in [1176..1199]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/26sept22no37b.txt','wb') # H4 series 
t= pickle.dumps(str(data))
w.write(t)
w.close()
# Out:
# 1905
# 1906
# 1907
# 1908
# 1909
# 1910
# 1911
# 1912
# 1913
# 1914
# 1915
# 1916
# 1917
# 1918
# 1919
# 1920
# 1921
# 1922
# 1923
# 1924
# 1925
# 1926
# 1927
# 1928
# 1929
# 1930
# 1931
# 1932
# 1933
# 1934
# 1935
# 1936
# 1937
# 1938
# 1939
# 1940
# 1941
# 1942
# 1943
# 1944
# 1945
# 1946
# 1947
# 1948
# 1949
# 1950
# 1951
# 1952
# 1953
# 1954
# 1955
# 1956
# 1957
# 1958
# 1959
# 1960
# 1961
# 1962
# 1963
# 1964
# 1965
# 1966
# 1967
# 1968
# 1969
# 1970
# 1971
# 1972
# 1973
# 1974
# 1975
# 1976
# 1977
# 1978
# 1979
# 1980
# 1981
# 1982
# 1983
# 1984
# 1985
# 1986
# 1987
# 1988
# 1989
# 1990
# 1991
# 1992
# 1993
# 1994
# 1995
# 1996
# 1997
# 1998
# 1999
# 2000
# 2001
# 2002
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2018
# 2019
# 2020
# 2021
# 2022
# 2023
# 2024
# 2025
# 2026
# 2027
# 2028
# 2029
# 2030
# 2031
# 2032
# 2033
# 2034
# 2035
# 2036
# 2037
# 2038
# 2039
# 2040
# 2041
# 2042
# 2043
# 2044
# 2045
# 2046
# ...
