# %%
def stripQuotationMarks(string):
    var('x')
    return sage_eval(string,locals={'x':x})

# %%
# from 'superlong H4 24sept22'
# print output snipped.
data=[]
import time
start=time.time()/60
for m in [2404..3610]:
    poly=H4(200,m)
    data=data+[[m,poly]]
    finish=time.time()/60
    print([m,poly.degree(),finish-start])
import pickle
wfile = open('/Users/barrybrent/26sept22no13.txt','wb') # H4 series 
s = pickle.dumps(str(data))
wfile.write(s)
wfile.close()

# %%
import pickle
rfile = open('/Users/barrybrent/26sept22no13.txt','rb') # H4 series
rs=pickle.load(rfile)
rfile.close()
s=stripQuotationMarks(rs)
print(len(s))
# Out:
# 1207

# %%
import pickle
rfile = open('/Users/barrybrent/26sept22no13.txt','rb') # H4 series
rs=pickle.load(rfile)
rfile.close()
s=stripQuotationMarks(rs)

data=[]
for k in [0..50]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/27sept22no2.txt','wb') # H4 series 
t= pickle.dumps(str(data))
w.write(t)
w.close()
# Out:
# 2404
# 2405
# 2406
# 2407
# 2408
# 2409
# 2410
# 2411
# 2412
# 2413
# 2414
# 2415
# 2416
# 2417
# 2418
# 2419
# 2420
# 2421
# 2422
# 2423
# 2424
# 2425
# 2426
# 2427
# 2428
# 2429
# 2430
# 2431
# 2432
# 2433
# 2434
# 2435
# 2436
# 2437
# 2438
# 2439
# 2440
# 2441
# 2442
# 2443
# 2444
# 2445
# 2446
# 2447
# 2448
# 2449
# 2450
# 2451
# 2452
# 2453
# 2454

# %%
import pickle
rfile = open('/Users/barrybrent/26sept22no13.txt','rb') # H4 series
rs=pickle.load(rfile)
rfile.close()
s=stripQuotationMarks(rs)



data=[]
for k in [51..100]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/27sept22no3.txt','wb') # H4 series 
t= pickle.dumps(str(data))
w.write(t)
w.close()

data=[]
for k in [101..150]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/27sept22no4.txt','wb') # H4 series 
t= pickle.dumps(str(data))
w.write(t)
w.close()

data=[]
for k in [151..200]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/27sept22no5.txt','wb') # H4 series 
t= pickle.dumps(str(data))
w.write(t)
w.close()

data=[]
for k in [201..250]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/27sept22no6.txt','wb') # H4 series 
t= pickle.dumps(str(data))
w.write(t)
w.close()

data=[]
for k in [251..300]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/27sept22no7.txt','wb') # H4 series 
t= pickle.dumps(str(data))
w.write(t)
w.close()

data=[]
for k in [301..350]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/27sept22no8.txt','wb') # H4 series 
t= pickle.dumps(str(data))
w.write(t)
w.close()

data=[]
for k in [351..400]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/27sept22no9.txt','wb') # H4 series 
t= pickle.dumps(str(data))
w.write(t)
w.close()

data=[]
for k in [401..430]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/27sept22no10.txt','wb') # H4 series 
t= pickle.dumps(str(data))
w.write(t)
w.close()

data=[]
for k in [431..460]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/27sept22no11.txt','wb') # H4 series 
t= pickle.dumps(str(data))
w.write(t)
w.close()

data=[]
for k in [461..490]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/27sept22no12.txt','wb') # H4 series 
t= pickle.dumps(str(data))
w.write(t)
w.close()

data=[]
for k in [491..520]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/27sept22no13.txt','wb') # H4 series 
t= pickle.dumps(str(data))
w.write(t)
w.close()

data=[]
for k in [521..550]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/27sept22no14.txt','wb') # H4 series 
t= pickle.dumps(str(data))
w.write(t)
w.close()

data=[]
for k in [551..580]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/27sept22no15.txt','wb') # H4 series 
t= pickle.dumps(str(data))
w.write(t)
w.close()

data=[]
for k in [581..600]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/27sept22no16.txt','wb') # H4 series 
t= pickle.dumps(str(data))
w.write(t)
w.close()

data=[]
for k in [601..620]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/27sept22no17.txt','wb') # H4 series 
t= pickle.dumps(str(data))
w.write(t)
w.close()

data=[]
for k in [621..640]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/27sept22no18.txt','wb') # H4 series 
t= pickle.dumps(str(data))
w.write(t)
w.close()

data=[]
for k in [641..660]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/27sept22no19.txt','wb') # H4 series 
t= pickle.dumps(str(data))
w.write(t)
w.close()

data=[]
for k in [661..680]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/27sept22no20.txt','wb') # H4 series 
t= pickle.dumps(str(data))
w.write(t)
w.close()

data=[]
for k in [681..700]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/27sept22no21.txt','wb') # H4 series 
t= pickle.dumps(str(data))
w.write(t)
w.close()

data=[]
for k in [701..720]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/27sept22no22.txt','wb') # H4 series 
t= pickle.dumps(str(data))
w.write(t)
w.close()

data=[]
for k in [721..740]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/27sept22no23.txt','wb') # H4 series 
t= pickle.dumps(str(data))
w.write(t)
w.close()

data=[]
for k in [741..760]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/27sept22no24.txt','wb') # H4 series 
t= pickle.dumps(str(data))
w.write(t)
w.close()

data=[]
for k in [761..780]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/27sept22no25.txt','wb') # H4 series 
t= pickle.dumps(str(data))
w.write(t)
w.close()

data=[]
for k in [781..800]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/27sept22no26.txt','wb') # H4 series 
t= pickle.dumps(str(data))
w.write(t)
w.close()

data=[]
for k in [801..820]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/27sept22no27.txt','wb') # H4 series 
t= pickle.dumps(str(data))
w.write(t)
w.close()

data=[]
for k in [821..840]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/27sept22no28.txt','wb') # H4 series 
t= pickle.dumps(str(data))
w.write(t)
w.close()
# Out:
# 2455
# 2456
# 2457
# 2458
# 2459
# 2460
# 2461
# 2462
# 2463
# 2464
# 2465
# 2466
# 2467
# 2468
# 2469
# 2470
# 2471
# 2472
# 2473
# 2474
# 2475
# 2476
# 2477
# 2478
# 2479
# 2480
# 2481
# 2482
# 2483
# 2484
# 2485
# 2486
# 2487
# 2488
# 2489
# 2490
# 2491
# 2492
# 2493
# 2494
# 2495
# 2496
# 2497
# 2498
# 2499
# 2500
# 2501
# 2502
# 2503
# 2504
# 2505
# 2506
# 2507
# 2508
# 2509
# 2510
# 2511
# 2512
# 2513
# 2514
# 2515
# 2516
# 2517
# 2518
# 2519
# 2520
# 2521
# 2522
# 2523
# 2524
# 2525
# 2526
# 2527
# 2528
# 2529
# 2530
# 2531
# 2532
# 2533
# 2534
# 2535
# 2536
# 2537
# 2538
# 2539
# 2540
# 2541
# 2542
# 2543
# 2544
# 2545
# 2546
# 2547
# 2548
# 2549
# 2550
# 2551
# 2552
# 2553
# 2554
# 2555
# 2556
# 2557
# 2558
# 2559
# 2560
# 2561
# 2562
# 2563
# 2564
# 2565
# 2566
# 2567
# 2568
# 2569
# 2570
# 2571
# 2572
# 2573
# 2574
# 2575
# 2576
# 2577
# 2578
# 2579
# 2580
# 2581
# 2582
# 2583
# 2584
# 2585
# 2586
# 2587
# 2588
# 2589
# 2590
# 2591
# 2592
# 2593
# 2594
# 2595
# 2596
# ...

# %%
import pickle
rfile = open('/Users/barrybrent/26sept22no13.txt','rb') # H4 series
rs=pickle.load(rfile)
rfile.close()
s=stripQuotationMarks(rs)



data=[]
for k in [841..850]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/27sept22no29.txt','wb') # H4 series 
t= pickle.dumps(str(data))
w.write(t)
w.close()

data=[]
for k in [851..860]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/27sept22no30.txt','wb') # H4 series 
t= pickle.dumps(str(data))
w.write(t)
w.close()

data=[]
for k in [861..870]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/27sept22no31.txt','wb') # H4 series 
t= pickle.dumps(str(data))
w.write(t)
w.close()

data=[]
for k in [871..880]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/27sept22no32.txt','wb') # H4 series 
t= pickle.dumps(str(data))
w.write(t)
w.close()

data=[]
for k in [881..890]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/27sept22no33.txt','wb') # H4 series 
t= pickle.dumps(str(data))
w.write(t)
w.close()

data=[]
for k in [891..900]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/27sept22no34.txt','wb') # H4 series 
t= pickle.dumps(str(data))
w.write(t)
w.close()

data=[]
for k in [901..910]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/27sept22no35.txt','wb') # H4 series 
t= pickle.dumps(str(data))
w.write(t)
w.close()

data=[]
for k in [911..920]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/27sept22no36.txt','wb') # H4 series 
t= pickle.dumps(str(data))
w.write(t)
w.close()

data=[]
for k in [921..930]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/27sept22no37.txt','wb') # H4 series 
t= pickle.dumps(str(data))
w.write(t)
w.close()

data=[]
for k in [931..940]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/27sept22no38.txt','wb') # H4 series 
t= pickle.dumps(str(data))
w.write(t)
w.close()

data=[]
for k in [941..950]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/27sept22no39.txt','wb') # H4 series 
t= pickle.dumps(str(data))
w.write(t)
w.close()

data=[]
for k in [951..960]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/27sept22no40.txt','wb') # H4 series 
t= pickle.dumps(str(data))
w.write(t)
w.close()

data=[]
for k in [961..970]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/27sept22no41.txt','wb') # H4 series 
t= pickle.dumps(str(data))
w.write(t)
w.close()

data=[]
for k in [971..980]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/27sept22no42.txt','wb') # H4 series 
t= pickle.dumps(str(data))
w.write(t)
w.close()

data=[]
for k in [981..990]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/27sept22no43.txt','wb') # H4 series 
t= pickle.dumps(str(data))
w.write(t)
w.close()

data=[]
for k in [991..1000]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/27sept22no44.txt','wb') # H4 series 
t= pickle.dumps(str(data))
w.write(t)
w.close()

data=[]
for k in [1001..1010]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/27sept22no45.txt','wb') # H4 series 
t= pickle.dumps(str(data))
w.write(t)
w.close()

data=[]
for k in [1011..1020]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/27sept22no46.txt','wb') # H4 series 
t= pickle.dumps(str(data))
w.write(t)
w.close()

data=[]
for k in [1021..1030]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/27sept22no47.txt','wb') # H4 series 
t= pickle.dumps(str(data))
w.write(t)
w.close()

data=[]
for k in [1031..1040]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/27sept22no48.txt','wb') # H4 series 
t= pickle.dumps(str(data))
w.write(t)
w.close()

data=[]
for k in [1041..1050]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/27sept22no49.txt','wb') # H4 series 
t= pickle.dumps(str(data))
w.write(t)
w.close()

data=[]
for k in [1051..1060]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/27sept22no50.txt','wb') # H4 series 
t= pickle.dumps(str(data))
w.write(t)
w.close()

data=[]
for k in [1061..1070]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/27sept22no51.txt','wb') # H4 series 
t= pickle.dumps(str(data))
w.write(t)
w.close()

data=[]
for k in [1071..1080]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/27sept22no52.txt','wb') # H4 series 
t= pickle.dumps(str(data))
w.write(t)
w.close()

data=[]
for k in [1081..1090]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/27sept22no53.txt','wb') # H4 series 
t= pickle.dumps(str(data))
w.write(t)
w.close()

data=[]
for k in [1091..1100]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/27sept22no54.txt','wb') # H4 series 
t= pickle.dumps(str(data))
w.write(t)
w.close()
# Out:
# 3245
# 3246
# 3247
# 3248
# 3249
# 3250
# 3251
# 3252
# 3253
# 3254
# 3255
# 3256
# 3257
# 3258
# 3259
# 3260
# 3261
# 3262
# 3263
# 3264
# 3265
# 3266
# 3267
# 3268
# 3269
# 3270
# 3271
# 3272
# 3273
# 3274
# 3275
# 3276
# 3277
# 3278
# 3279
# 3280
# 3281
# 3282
# 3283
# 3284
# 3285
# 3286
# 3287
# 3288
# 3289
# 3290
# 3291
# 3292
# 3293
# 3294
# 3295
# 3296
# 3297
# 3298
# 3299
# 3300
# 3301
# 3302
# 3303
# 3304
# 3305
# 3306
# 3307
# 3308
# 3309
# 3310
# 3311
# 3312
# 3313
# 3314
# 3315
# 3316
# 3317
# 3318
# 3319
# 3320
# 3321
# 3322
# 3323
# 3324
# 3325
# 3326
# 3327
# 3328
# 3329
# 3330
# 3331
# 3332
# 3333
# 3334
# 3335
# 3336
# 3337
# 3338
# 3339
# 3340
# 3341
# 3342
# 3343
# 3344
# 3345
# 3346
# 3347
# 3348
# 3349
# 3350
# 3351
# 3352
# 3353
# 3354
# 3355
# 3356
# 3357
# 3358
# 3359
# 3360
# 3361
# 3362
# 3363
# 3364
# 3365
# 3366
# 3367
# 3368
# 3369
# 3370
# 3371
# 3372
# 3373
# 3374
# 3375
# 3376
# 3377
# 3378
# 3379
# 3380
# 3381
# 3382
# 3383
# 3384
# 3385
# 3386
# ...

# %%
import pickle
rfile = open('/Users/barrybrent/26sept22no13.txt','rb') # H4 series
rs=pickle.load(rfile)
rfile.close()
s=stripQuotationMarks(rs)



data=[]
for k in [1101..1120]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/27sept22no55.txt','wb') # H4 series 
t= pickle.dumps(str(data))
w.write(t)
w.close()

data=[]
for k in [1121..1130]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/27sept22no56.txt','wb') # H4 series 
t= pickle.dumps(str(data))
w.write(t)
w.close()

data=[]
for k in [1131..1140]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/27sept22no57.txt','wb') # H4 series 
t= pickle.dumps(str(data))
w.write(t)
w.close()

data=[]
for k in [1141..1150]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/27sept22no58.txt','wb') # H4 series 
t= pickle.dumps(str(data))
w.write(t)
w.close()

data=[]
for k in [1151..1160]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/27sept22no59.txt','wb') # H4 series 
t= pickle.dumps(str(data))
w.write(t)
w.close()

data=[]
for k in [1161..1170]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/27sept22no60.txt','wb') # H4 series 
t= pickle.dumps(str(data))
w.write(t)
w.close()

data=[]
for k in [1171..1180]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/27sept22no61.txt','wb') # H4 series 
t= pickle.dumps(str(data))
w.write(t)
w.close()

data=[]
for k in [1181..1190]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/27sept22no62.txt','wb') # H4 series 
t= pickle.dumps(str(data))
w.write(t)
w.close()

data=[]
for k in [1191..1200]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/27sept22no63.txt','wb') # H4 series 
t= pickle.dumps(str(data))
w.write(t)
w.close()

data=[]
for k in [1201..1206]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/27sept22no64.txt','wb') # H4 series 
t= pickle.dumps(str(data))
w.write(t)
w.close()
# Out:
# 3505
# 3506
# 3507
# 3508
# 3509
# 3510
# 3511
# 3512
# 3513
# 3514
# 3515
# 3516
# 3517
# 3518
# 3519
# 3520
# 3521
# 3522
# 3523
# 3524
# 3525
# 3526
# 3527
# 3528
# 3529
# 3530
# 3531
# 3532
# 3533
# 3534
# 3535
# 3536
# 3537
# 3538
# 3539
# 3540
# 3541
# 3542
# 3543
# 3544
# 3545
# 3546
# 3547
# 3548
# 3549
# 3550
# 3551
# 3552
# 3553
# 3554
# 3555
# 3556
# 3557
# 3558
# 3559
# 3560
# 3561
# 3562
# 3563
# 3564
# 3565
# 3566
# 3567
# 3568
# 3569
# 3570
# 3571
# 3572
# 3573
# 3574
# 3575
# 3576
# 3577
# 3578
# 3579
# 3580
# 3581
# 3582
# 3583
# 3584
# 3585
# 3586
# 3587
# 3588
# 3589
# 3590
# 3591
# 3592
# 3593
# 3594
# 3595
# 3596
# 3597
# 3598
# 3599
# 3600
# 3601
# 3602
# 3603
# 3604
# 3605
# 3606
# 3607
# 3608
# 3609
# 3610
