# %%
def stripQuotationMarks(string):
    var('x')
    return sage_eval(string,locals={'x':x})

# %%
# from 'superlong H6 24sept22'
# print output snipped.
data=[]
import time
start=time.time()/60
for m in [3611..4818]:
    poly=H6(200,m)
    data=data+[[m,poly]]
    finish=time.time()/60
    print([m,poly.degree(),finish-start])
import pickle
wfile = open('/Users/barrybrent/29sept22no1.txt','wb') # H6 series 
s = pickle.dumps(str(data))
wfile.write(s)
wfile.close()

# %%
import pickle
rfile = open('/Users/barrybrent/29sept22no1.txt','rb') # H6 series 
rs=pickle.load(rfile)
rfile.close()
s=stripQuotationMarks(rs)
print(len(s))
# Out:
# 1208

# %%
import pickle

rfile = open('/Users/barrybrent/29sept22no1.txt','rb') # H6 series 
rs=pickle.load(rfile)
rfile.close()
s=stripQuotationMarks(rs)

data=[]
for k in [0..20]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/30sept22no1.txt','wb') # H6 series 
t= pickle.dumps(str(data))
w.write(t)
w.close()


data=[]
for k in [21..40]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/30sept22no2.txt','wb')  
t= pickle.dumps(str(data))
w.write(t)
w.close()


data=[]
for k in [41..60]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/30sept22no3.txt','wb') 
t= pickle.dumps(str(data))
w.write(t)
w.close()


data=[]
for k in [61..80]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/30sept22no4.txt','wb')  
t= pickle.dumps(str(data))
w.write(t)
w.close()


data=[]
for k in [81..100]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/30sept22no4.txt','wb')  
t= pickle.dumps(str(data))
w.write(t)
w.close()


data=[]
for k in [101..120]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/30sept22no5.txt','wb') 
t= pickle.dumps(str(data))
w.write(t)
w.close()


data=[]
for k in [121..140]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/30sept22no6.txt','wb') 
t= pickle.dumps(str(data))
w.write(t)
w.close()


data=[]
for k in [141..160]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/30sept22no7.txt','wb') 
t= pickle.dumps(str(data))
w.write(t)
w.close()


data=[]
for k in [161..180]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/30sept22no8.txt','wb') 
t= pickle.dumps(str(data))
w.write(t)
w.close()


data=[]
for k in [181..200]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/30sept22no9.txt','wb') 
################################################## skipped 2j!
t= pickle.dumps(str(data))
w.write(t)
w.close()

data=[]
for k in [201..220]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/30sept22no10.txt','wb') 
t= pickle.dumps(str(data))
w.write(t)
w.close()


data=[]
for k in [221..240]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/30sept22no11.txt','wb') 
t= pickle.dumps(str(data))
w.write(t)
w.close()


data=[]
for k in [241..260]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/30sept22no12.txt','wb') 
t= pickle.dumps(str(data))
w.write(t)
w.close()


data=[]
for k in [261..280]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/30sept22no13.txt','wb') 
t= pickle.dumps(str(data))
w.write(t)
w.close()


data=[]
for k in [281..300]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/30sept22no14.txt','wb') 
t= pickle.dumps(str(data))
w.write(t)
w.close()


data=[]
for k in [301..320]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/30sept22no15.txt','wb') 
t= pickle.dumps(str(data))
w.write(t)
w.close()


data=[]
for k in [321..340]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/30sept22no16.txt','wb') 
t= pickle.dumps(str(data))
w.write(t)
w.close()


data=[]
for k in [341..360]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/30sept22no17.txt','wb')  
t= pickle.dumps(str(data))
w.write(t)
w.close()


data=[]
for k in [361..380]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/30sept22no18.txt','wb') 
t= pickle.dumps(str(data))
w.write(t)
w.close()


data=[]
for k in [381..400]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/30sept22no19.txt','wb') 
t= pickle.dumps(str(data))
w.write(t)
w.close()



data=[]
for k in [401..420]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/30sept22no20.txt','wb')  
t= pickle.dumps(str(data))
w.write(t)
w.close()


data=[]
for k in [421..440]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/30sept22no21.txt','wb') 
t= pickle.dumps(str(data))
w.write(t)
w.close()


data=[]
for k in [441..460]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/30sept22no22.txt','wb') 
t= pickle.dumps(str(data))
w.write(t)
w.close()


data=[]
for k in [461..480]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/30sept22no23.txt','wb') 
t= pickle.dumps(str(data))
w.write(t)
w.close()


data=[]
for k in [481..500]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/30sept22no24.txt','wb') 
t= pickle.dumps(str(data))
w.write(t)
w.close()


data=[]
for k in [501..520]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/30sept22no24.txt','wb') 
t= pickle.dumps(str(data))
w.write(t)
w.close()


data=[]
for k in [521..540]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/30sept22no25.txt','wb') 
t= pickle.dumps(str(data))
w.write(t)
w.close()


data=[]
for k in [541..560]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/30sept22no26.txt','wb') 
t= pickle.dumps(str(data))
w.write(t)
w.close()


data=[]
for k in [561..580]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/30sept22no27.txt','wb') 
t= pickle.dumps(str(data))
w.write(t)
w.close()


data=[]
for k in [581..600]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/30sept22no28.txt','wb') 
t= pickle.dumps(str(data))
w.write(t)
w.close()



data=[]
for k in [601..620]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/30sept22no29.txt','wb') 
t= pickle.dumps(str(data))
w.write(t)
w.close()


data=[]
for k in [621..640]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/30sept22no30.txt','wb') 
t= pickle.dumps(str(data))
w.write(t)
w.close()


data=[]
for k in [641..660]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/30sept22no31.txt','wb')  
t= pickle.dumps(str(data))
w.write(t)
w.close()


data=[]
for k in [661..680]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/30sept22no32.txt','wb')
t= pickle.dumps(str(data))
w.write(t)
w.close()


data=[]
for k in [681..700]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/30sept22no33.txt','wb') 
t= pickle.dumps(str(data))
w.write(t)
w.close()


data=[]
for k in [701..720]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/30sept22no34.txt','wb') 
t= pickle.dumps(str(data))
w.write(t)
w.close()


data=[]
for k in [721..740]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/30sept22no35.txt','wb') 
t= pickle.dumps(str(data))
w.write(t)
w.close()


data=[]
for k in [741..760]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/30sept22no36.txt','wb') 
t= pickle.dumps(str(data))
w.write(t)
w.close()


data=[]
for k in [761..780]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/30sept22no37.txt','wb') 
t= pickle.dumps(str(data))
w.write(t)
w.close()


data=[]
for k in [781..800]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/30sept22no38.txt','wb')  
t= pickle.dumps(str(data))
w.write(t)
w.close()



data=[]
for k in [801..820]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/30sept22no39.txt','wb') 
t= pickle.dumps(str(data))
w.write(t)
w.close()


data=[]
for k in [821..840]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/30sept22no40.txt','wb')  
t= pickle.dumps(str(data))
w.write(t)
w.close()


data=[]
for k in [841..860]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/30sept22no41.txt','wb') 
t= pickle.dumps(str(data))
w.write(t)
w.close()


data=[]
for k in [861..880]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/30sept22no42.txt','wb') 
t= pickle.dumps(str(data))
w.write(t)
w.close()


data=[]
for k in [881..900]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/30sept22no43.txt','wb') 
t= pickle.dumps(str(data))
w.write(t)
w.close()


data=[]
for k in [901..920]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/30sept22no44.txt','wb') 
t= pickle.dumps(str(data))
w.write(t)
w.close()


data=[]
for k in [921..940]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/30sept22no45.txt','wb')
t= pickle.dumps(str(data))
w.write(t)
w.close()


data=[]
for k in [941..960]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/30sept22no46.txt','wb') 
t= pickle.dumps(str(data))
w.write(t)
w.close()


data=[]
for k in [961..980]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/30sept22no47.txt','wb') 
t= pickle.dumps(str(data))
w.write(t)
w.close()


data=[]
for k in [981..1000]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/30sept22no48.txt','wb') 
t= pickle.dumps(str(data))
w.write(t)
w.close()



data=[]
for k in [1001..1020]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/30sept22no49.txt','wb')
t= pickle.dumps(str(data))
w.write(t)
w.close()


data=[]
for k in [1021..1040]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/30sept22no50.txt','wb') 
t= pickle.dumps(str(data))
w.write(t)
w.close()


data=[]
for k in [1041..1060]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/30sept22no51.txt','wb') 
t= pickle.dumps(str(data))
w.write(t)
w.close()


data=[]
for k in [1061..1080]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/30sept22no52.txt','wb') 
t= pickle.dumps(str(data))
w.write(t)
w.close()


data=[]
for k in [1081..1100]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/30sept22no53.txt','wb') 
t= pickle.dumps(str(data))
w.write(t)
w.close()


data=[]
for k in [1101..1120]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/30sept22no54.txt','wb') 
t= pickle.dumps(str(data))
w.write(t)
w.close()


data=[]
for k in [1121..1140]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/30sept22no55.txt','wb')  
t= pickle.dumps(str(data))
w.write(t)
w.close()


data=[]
for k in [1141..1160]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/30sept22no56.txt','wb')
t= pickle.dumps(str(data))
w.write(t)
w.close()


data=[]
for k in [1161..1180]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/30sept22no57.txt','wb') 
t= pickle.dumps(str(data))
w.write(t)
w.close()


data=[]
for k in [1181..1190]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/30sept22no58.txt','wb') 
t= pickle.dumps(str(data))
w.write(t)
w.close()


data=[]
for k in [1191..1207]:
    pair=s[k]
    data=data+[pair]
    print(pair[0])
w = open('/Users/barrybrent/30sept22no59.txt','wb') 
t= pickle.dumps(str(data))
w.write(t)
w.close()
# Out:
# 3611
# 3612
# 3613
# 3614
# 3615
# 3616
# 3617
# 3618
# 3619
# 3620
# 3621
# 3622
# 3623
# 3624
# 3625
# 3626
# 3627
# 3628
# 3629
# 3630
# 3631
# 3632
# 3633
# 3634
# 3635
# 3636
# 3637
# 3638
# 3639
# 3640
# 3641
# 3642
# 3643
# 3644
# 3645
# 3646
# 3647
# 3648
# 3649
# 3650
# 3651
# 3652
# 3653
# 3654
# 3655
# 3656
# 3657
# 3658
# 3659
# 3660
# 3661
# 3662
# 3663
# 3664
# 3665
# 3666
# 3667
# 3668
# 3669
# 3670
# 3671
# 3672
# 3673
# 3674
# 3675
# 3676
# 3677
# 3678
# 3679
# 3680
# 3681
# 3682
# 3683
# 3684
# 3685
# 3686
# 3687
# 3688
# 3689
# 3690
# 3691
# 3692
# 3693
# 3694
# 3695
# 3696
# 3697
# 3698
# 3699
# 3700
# 3701
# 3702
# 3703
# 3704
# 3705
# 3706
# 3707
# 3708
# 3709
# 3710
# 3711
# 3712
# 3713
# 3714
# 3715
# 3716
# 3717
# 3718
# 3719
# 3720
# 3721
# 3722
# 3723
# 3724
# 3725
# 3726
# 3727
# 3728
# 3729
# 3730
# 3731
# 3732
# 3733
# 3734
# 3735
# 3736
# 3737
# 3738
# 3739
# 3740
# 3741
# 3742
# 3743
# 3744
# 3745
# 3746
# 3747
# 3748
# 3749
# 3750
# 3751
# 3752
# ...
